# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/taobrienlbl/advanced_earth_science_data_analysis/blob/fall_2025_iub/content/lessons/01_fundamentals/01b_madhava_pi_calculation.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# # Madhava-Leibniz π calculation
#
# <div style="max-width:720px"><div style="position:relative;padding-bottom:56.25%"><iframe id="kaltura_player" src='https://cdnapisec.kaltura.com/p/1751071/embedPlaykitJs/uiconf_id/55382703?iframeembed=true&amp;entry_id=1_so5cyb33&amp;config%5Bprovider%5D=%7B%22widgetId%22%3A%221_193jmsqz%22%7D&amp;config%5Bplayback%5D=%7B%22startTime%22%3A0%7D'  allowfullscreen webkitallowfullscreen mozAllowFullScreen allow="autoplay *; fullscreen *; encrypted-media *" sandbox="allow-downloads allow-forms allow-same-origin allow-scripts allow-top-navigation allow-pointer-lock allow-popups allow-modals allow-orientation-lock allow-popups-to-escape-sandbox allow-presentation allow-top-navigation-by-user-activation" title="EAS G-690 Week 1 - pi approximation workalong" style="position:absolute;top:0;left:0;width:100%;height:100%;border:0"></iframe></div></div>
#
# Click [here](https://iu.mediaspace.kaltura.com/media/t/1_so5cyb33) to go to the Kaltura video page if there are issues playing the above video.

# %% [markdown]
# This notebook is designed to be a live demonstration of Python fundamentals applied to calculating π using the [Madhava-Leibniz series](https://en.wikipedia.org/wiki/Approximations_of_%CF%80#Middle_Ages)
#
# The approximation is simple:
#
# $$ \pi \approx 4 \cdot \left(1 - \frac{1}{3} + \frac{1}{5} - \frac{1}{7} + \frac{1}{9} \ldots -(-1)^n \frac{1}{2n - 1}  \right) $$
#
# Key conceptual and coding vocabulary to watch for:
#
# * *comments*: anything starting with, and to the right of, `#`
# * *flow control*: `for` loops
# * *flow control*: `if` and `else` statements
# * `=` - the variable definition operator; read `pi = 0` as 'computer, store the 0 in the variable named pi'
# * `==` - the evaluation operator (checks if two things are equivalent)
# * `[]` - an empty list
# * `.append()` - add a variable/quantity/etc. to the end of a list
# * `range(a,b)` - creates a list of integers between [a,b) (not including b)
# * `+`, `-`, `*`, `/` - the addition, subtraction, multiplication, and division operators
# * `x**y` - the power operator; read as 'x to the y'
# * `print(x)` - prints the contents of x
# * indentation - why are some lines indented in python and not other?  What happens if you change this?

# %%
# remove this comment and add your pi calculation code here

# %% [markdown]
# (want the solution?  Find it [here](https://github.com/taobrienlbl/advanced_earth_science_data_analysis/blob/fall_2025_iub/content/lessons/01_fundamentals/01b_madhava_pi_calculation_SOLUTION.ipynb))
